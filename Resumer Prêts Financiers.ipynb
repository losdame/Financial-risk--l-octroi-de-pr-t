# %% [markdown]
# <div style="border-radius:10px; border:#B7B7A4 solid; padding:15px; background-color:#F0EFEB; font-size:110%; text-align:center; margin: 0 auto; width: fit-content;">
#
#   <p style="display: inline-block; padding: 7px; background-color: #28a745; color: #F0EFEB; text-decoration: none; border-radius: 5px; font-size: 180%; border: 1.5px solid #283618; font-family: 'Times New Roman', serif;">
#     Risque Financier : Approbation des Prêts 📈
#   </p>
#
#   <p style="font-size: 120%; color: #6B705C; margin-top: 10px;">
#     <span style="font-weight: bold;">Created by Serigne Dame LO  04/11/2024 👍</span>
#   </p>
# </div>

# %% [markdown]
# # **Aperçu**

# %% [markdown]
# L’objectif de ce projet était de développer un modèle prédictif utilisant des techniques de machine learning pour déterminer si un prêt financier doit être approuvé ou non. L’analyse s’est appuyée sur une base de données personnelles et financière des clients d'une banque. Le modèle final de CatBoost a atteint une AUC de 98 %, une précision de 96 %, une accuracy de 98,38 %, un score F1 de 96,65 % et un rappel de 97,30 %. L’analyse a révélé que des caractéristiques telles que le score de risque, le ratio total dettes revenus, le taux d'intérêt, le revenu mensuel, le score de crédit et le montant du prêt sont les plus influentes dans la prédiction des risques financiers liés au prêt.

# %% [markdown]
# # **Compréhension**

# %% [markdown]
# Baobab Finance souhaite optimiser son processus d’octroi de prêts bancaires afin de réduire les risques de défaut et d'améliorer la rentabilité. Pour ce faire, il est essentiel d'analyser les données financières disponibles afin d'identifier les facteurs qui influencent la décision d'accorder un prêt et de fournir des recommandations pour améliorer la prise de décisions.

# %% [markdown]
# # **Les données**

# %% [markdown]
# L’ensemble des données fourni par l'entreprise Baobab Finance contient 20000 enregistrements et 36 variables. Parmi ces caractéristiques on peut citer l'âge, le risque de crédit, le taux d'intérêt, le statut de propriété, le niveau d'étude ou  le fait qu'un prêt a été approuvé ou non.

# %% [markdown]
# Le graphique en barres ci-dessous illustre la répartition des clients par prêt approuvé ou non.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # **Modélisation et évaluation**

# %% [markdown]
# Ln modèle de CatBoost avec 10 arbres de décision a été retenu, parmi les cinq modèles utilisés, pour mesurer l'importance de chaque caractéristique dans la prise de décidion consernant les prêts bancaires. Les indicateurs de performance du modèle sont les suivants :
#
# * **Accuracy** : 98,38 %
#
# * **Précision** : 96 %
#
# * **Recall** : 97,30 %
#
# * **F1 Score** : 96,65 %
#
# * **AUC** : 98 %

# %% [markdown]
# Le barplot ci-dessous montre que le score de risque, le ratio total dettes revenus, le taux d'intérêt, le score de crédit et le revenu mensuel ont été identifiés comme les facteurs les plus importants dans l'octroi de prêts bancaires.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Les résultats montrent que les variables telles que: le score de risque, le ratio total dettes revenus, le taux d'intérêt, le revenu mensuel, le score de crédit et le montant du prêt jouent un rôle important dans l'approbation des prêts. Ainsi certaines recommandations ont été proposées:
#
# * **Score de Risque** :
#    - **Utiliser des outils d'évaluation améliorés** : Implémentez des systèmes d'évaluation pour mieux prédire le score de risque des emprunteurs. Cela pourrait inclure des modèles prédictifs avancés ou des techniques d'analyse de données pour identifier les facteurs de risque.
#    - **Éducation des clients** : Fournissez des ressources éducatives pour aider les emprunteurs à comprendre comment leur score de risque est calculé et comment ils peuvent l'améliorer.
#
# * **Ratio Total Dettes/Revenus** :
#    - **Établir des seuils de référence** : Définissez des seuils de ratio dettes/revenus acceptables pour approuver les prêts et éviter le surendettement.
#    - **Conseils financiers** : Proposez des conseils aux emprunteurs sur la gestion de leurs dettes, les aidant à maintenir un ratio favorable.
# * **Taux d'Intérêt** :
#    - **Offrir des options de taux variables** : Considérez la possibilité d'offrir des taux d'intérêt variables basés sur le profil de risque de l'emprunteur. Cela peut attirer des emprunteurs avec de bons antécédents de crédit.
#    - **Transparence des conditions** : Assurer à ce que les conditions de taux d'intérêt soient clairement communiquées aux clients pour éviter toute confusion lors de l'approbation des prêts.
#
# * **Score de Crédit** :
#    - **Programmes de fidélité** : Mettez en place des programmes de fidélité ou de récompense pour les clients qui maintiennent un bon score de crédit, ce qui peut encourager un comportement financier responsable.
#    - **Revues régulières** : Encouragez les emprunteurs à vérifier régulièrement leur score de crédit et à corriger toute information erronée, ce qui peut améliorer leur capacité à obtenir un prêt.
#
# * **Revenu Mensuel** :
#    - **Assistance à l'emploi** : Proposez des programmes d'assistance à l'emploi ou de formation qui peuvent aider les emprunteurs à augmenter leurs revenus, rendant ainsi leurs demandes de prêt plus solides.

# %% [markdown]
# > **Created by Serigne Dame LO  04/11/2024 👍**
# > **serignedame2.lo@ucad.edu.sn**
# > **[e-Portfolio](https://github.com/losdame)**
