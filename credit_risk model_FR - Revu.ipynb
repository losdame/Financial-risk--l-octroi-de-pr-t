# %% [markdown]
# <div style="border-radius:10px; border:#B7B7A4 solid; padding:15px; background-color:#F0EFEB; font-size:110%; text-align:left">
#
#   <p style="display: inline-block; padding: 7px; background-color: #000000; color: #F0EFEB; text-decoration: none; border-raius: 5px 5px; font-size: 180%; text-align: left; border: 1.5px solid #283618; font-family: 'New Times Roman', serif;">Financial Risk for Loan Approval📈</p>

# %% [markdown]
# <a name="0"></a>
# # **<h1 id="0" style="background-color:#F0EFEB;font-family:newtimeroman;font-size:150%;color:#28a745;text-align:center;border-radius:15px 15px;padding:7px;border:solid 3px #28a745;">Risque fiancier et l'octroi de Prêt 📈</h1>**
#
# > **Created by Serigne Dame LO  04/11/2024 👍**
# > **serignedame2.lo@ucad.edu.sn**
# > **[e-Portfolio](https://github.com/losdame)**

# %% [markdown]
# # **Table des matières**
#
# - [1. PLAN](#plan)
# - [2. ANALYSE](#analyse)
# - [3. Modélisation](#modelisation)
# - [4. Conclusion et Recommandations](#conclusion-et-recommandations)

# %% [markdown]
# <a id="tic"></a>
# - [10. RETOUR](#10)

# %% [markdown]
# - [2. PLAN](#1-plan)

# %% [markdown]
# <span style="color: #2E8B57; font-size: 24px; font-weight: bold;">📁 Description du Projet</span>
#
#
# Il s'agit d'effectuer une évaluation comparative entre modèles d'apprentissage automatique en évaluant leur performance par le biais de métriques pertinentes dans le cadre de l'octroi des crédits bancaires. Les modèles utilisés sont l'arbre de décision, la forêt aléatoire, le gradiant boosting, la catégorie boosting et la régression logistique. Le choix de ces modèles est porté par leur performance, leur capacité d'interprétation, leur robustesse et leur popularité dans la détermination du risque. caractéristiques dont l'âge, le score de risque, le taux d'intérêt, le statut de propriété, le niveau d'étude ou le fait qu'un prêt a été approuvé ou non. La base de données utilisée dans cet exercice est constituée de 20000 demandes de prêts bancaires des clients d'une banque avec 36 caractéristiques dont l'âge, le score de risque, le taux d'intérêt, le statut de propriété, le niveau d'étude ou le fait qu'un prêt a été approuvé ou non.

# %% [markdown]
# #  **<h2 id="1-plan" style="background-color:#F0EFEB;font-family:newtimeroman;font-size:150%;color:#28a745;text-align:center;border-radius:15px 15px;padding:7px;border:solid 3px #28a745;">PLAN</h2>**

# %% [markdown]
# L'objectif est de concevoir un modèle capable d'indiquer si une demande de prêt doit être approuvée ou refusée.

# %% [markdown]
# La base est composée de 20000 enregistrements et de 36 variables.
#
# | **Variable**                                     | **Description**                                                                                     |
# |--------------------------------------------------|-----------------------------------------------------------------------------------------------------|
# | **DateDeDemande**                               | Date à laquelle la demande de prêt a été soumise.                                                |
# | **Age**                                         | Âge de l'emprunteur en années.                                                                     |
# | **RevenuAnnuel**                                | Revenu total de l'emprunteur sur une base annuelle.                                              |
# | **ScoreDeCrédit**                               | Score de crédit de l'emprunteur, indiquant sa solvabilité.                                       |
# | **StatutDemploi**                               | Statut d'emploi de l'emprunteur (employé, indépendant, chômeur, etc.).                           |
# | **NiveauDEducation**                            | Niveau d'éducation atteint par l'emprunteur (par exemple, lycée, licence, master).                |
# | **Expérience**                                  | Nombre d'années d'expérience professionnelle de l'emprunteur.                                     |
# | **MontantDuPrêt**                               | Montant total du prêt demandé par l'emprunteur.                                                  |
# | **DuréeDuPrêt**                                 | Durée du prêt en mois ou en années.                                                               |
# | **StatutMarital**                               | Statut marital de l'emprunteur (célibataire, marié, divorcé, etc.).                               |
# | **NombreDeDépendants**                          | Nombre de personnes à charge de l'emprunteur.                                                    |
# | **StatutDePropriété**                           | Indique si l'emprunteur est propriétaire, locataire ou autre.                                     |
# | **PaiementsMensuelsDeDettes**                  | Montant total des paiements mensuels de dettes de l'emprunteur.                                   |
# | **TauxDutilisationDesCartesDeCrédit**          | Pourcentage de crédit utilisé par rapport au crédit total disponible.                             |
# | **NombreDeLignesDeCréditOuvertes**             | Nombre de comptes de crédit ouverts par l'emprunteur.                                            |
# | **NombreDeDemandesDeCrédit**                   | Nombre de demandes de crédit effectuées par l'emprunteur dans une période donnée.                 |
# | **RatioDettesRevenus**                          | Ratio entre les dettes et le revenu annuel de l'em

# %% [markdown]
# ## Step 1. Imports
#
# *   Import packages
# *   Téléchatger la base

# %% [markdown]
# ### Import packages

# %%
# Import packages

# Pour la manipulation des données
import pandas as pd
import numpy as np

# Pour la visualisation des données
import matplotlib.pyplot as plt
import seaborn as sns

# Pour la modélisation et les métriques 

from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, train_test_split, PredefinedSplit, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier, BaggingClassifier
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score, roc_auc_score,roc_curve, auc, make_scorer, confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.neighbors import KNeighborsClassifier

from xgboost import XGBClassifier, plot_importance
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier


# Pour les warnings et l'affichage
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)
# Out:
# c:\Users\7MAKSACOD PC\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# ### Load dataset

# %%
# Télécharger les données 

df=pd.read_csv(r"E:\e_Learning\CREDIT RISK\prêts.csv")

# Afficher les premières lignes du dataframe

df.head()
# Out:
#   DateDeDemande  Age  RevenuAnnuel  ScoreDeCrédit StatutDemploi  \
# 0    2018-01-01   45         39948            617       Employé
# 1    2018-01-02   38         39709            628       Employé
# 2    2018-01-03   47         40724            570       Employé
# 3    2018-01-04   58         69084            545       Employé
# 4    2018-01-05   37        103264            594       Employé
#
#   NiveauDEducation  Expérience  MontantDuPrêt  DuréeDuPrêt StatutMarital  \
# 0         Maîtrise          22          13152           48         Marié
# 1          Associé          15          26045           48   Célibataire
# 2          Licence          26          17627           36         Marié
# 3            Lycée          34          37898           96   Célibataire
# 4          Associé          17           9184           36         Marié
#
#    NombreDeDépendants StatutDePropriété  PaiementsMensuelsDeDettes  \
# 0                   2      Propriétaire                        183
# ...

# %% [markdown]
# ## Step 2.  l'Exploration initiale des données

# %% [markdown]
# ### Les informations de base

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 36 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   DateDeDemande                      20000 non-null  object
#  1   Age                                20000 non-null  int64
#  2   RevenuAnnuel                       20000 non-null  int64
#  3   ScoreDeCrédit                      20000 non-null  int64
#  4   StatutDemploi                      20000 non-null  object
#  5   NiveauDEducation                   20000 non-null  object
#  6   Expérience                         20000 non-null  int64
#  7   MontantDuPrêt                      20000 non-null  int64
#  8   DuréeDuPrêt                        20000 non-null  int64
#  9   StatutMarital                      20000 non-null  object
#  10  NombreDeDépendants                 20000 non-null  int64
# ...

# %% [markdown]
# ### La statistiques descriptives

# %%
df.describe()
# Out:
#                 Age   RevenuAnnuel  ScoreDeCrédit    Expérience  \
# count  20000.000000   20000.000000   20000.000000  20000.000000
# mean      39.752600   59161.473550     571.612400     17.522750
# std       11.622713   40350.845168      50.997358     11.316836
# min       18.000000   15000.000000     343.000000      0.000000
# 25%       32.000000   31679.000000     540.000000      9.000000
# 50%       40.000000   48566.000000     578.000000     17.000000
# 75%       48.000000   74391.000000     609.000000     25.000000
# max       80.000000  485341.000000     712.000000     61.000000
#
#        MontantDuPrêt   DuréeDuPrêt  NombreDeDépendants  \
# count   20000.000000  20000.000000        20000.000000
# mean    24882.867800     54.057000            1.517300
# std     13427.421217     24.664857            1.386325
# min      3674.000000     12.000000            0.000000
# 25%     15575.000000     36.000000            0.000000
# ...

# %% [markdown]
# ### Recherche de valeur manquante

# %%
plt.figure(figsize = (20, 5))

plt.subplot(1, 3, 1)
plt.title("Valeur manquante")
sns.heatmap(df.isnull(),cmap='Greens')
# Out:
# <Axes: title={'center': 'Valeur manquante'}>

# %%
df.isna().sum()
# Out:
# DateDeDemande                        0
# Age                                  0
# RevenuAnnuel                         0
# ScoreDeCrédit                        0
# StatutDemploi                        0
# NiveauDEducation                     0
# Expérience                           0
# MontantDuPrêt                        0
# DuréeDuPrêt                          0
# StatutMarital                        0
# NombreDeDépendants                   0
# StatutDePropriété                    0
# PaiementsMensuelsDeDettes            0
# TauxDutilisationDesCartesDeCrédit    0
# NombreDeLignesDeCréditOuvertes       0
# NombreDeDemandesDeCrédit             0
# RatioDettesRevenus                   0
# HistoriqueDeFaillite                 0
# ObjectifDuPrêt                       0
# DéfautsPrécédentsSurPrêts            0
# HistoriqueDesPaiements               0
# DuréeDeHistoriqueDeCrédit            0
# SoldeDuCompteÉpargne                 0
# SoldeDuCompteCourant                 0
# ...

# %% [markdown]
# Il n'y a pas de valeur manquante dans cette base.

# %% [markdown]
# ### Les valeurs redondantes

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Il n'y a pas de valeur redondante dans cette base.

# %%
df.describe()
# Out:
#                 Age   RevenuAnnuel  ScoreDeCrédit    Expérience  \
# count  20000.000000   20000.000000   20000.000000  20000.000000
# mean      39.752600   59161.473550     571.612400     17.522750
# std       11.622713   40350.845168      50.997358     11.316836
# min       18.000000   15000.000000     343.000000      0.000000
# 25%       32.000000   31679.000000     540.000000      9.000000
# 50%       40.000000   48566.000000     578.000000     17.000000
# 75%       48.000000   74391.000000     609.000000     25.000000
# max       80.000000  485341.000000     712.000000     61.000000
#
#        MontantDuPrêt   DuréeDuPrêt  NombreDeDépendants  \
# count   20000.000000  20000.000000        20000.000000
# mean    24882.867800     54.057000            1.517300
# std     13427.421217     24.664857            1.386325
# min      3674.000000     12.000000            0.000000
# 25%     15575.000000     36.000000            0.000000
# ...

# %% [markdown]
# ### Outliers

# %%
# Création de la figure et des sous-graphes
fig, ax = plt.subplots(2, 2, figsize=(12, 6))

# Boxplots pour le Score de Crédit et Prêt Approuvé
sns.boxplot(data=df, x="ScoreDeCrédit", y="PrêtApprouvé", orient='h', showfliers=False, ax=ax[0, 1])
ax[0, 1].set_title('Boxplot : Score de Crédit vs Prêt Approuvé (sans valeurs aberrantes)')

sns.boxplot(data=df, x="ScoreDeCrédit", y="PrêtApprouvé", orient='h', ax=ax[0, 0])
ax[0, 0].set_title('Boxplot : Score de Crédit vs Prêt Approuvé')

# Boxplots pour l'Expérience et Prêt Approuvé
sns.boxplot(data=df, x="Expérience", y="PrêtApprouvé", orient='h', showfliers=False, ax=ax[1, 1])
ax[1, 1].set_title('Boxplot : Expérience vs Prêt Approuvé (sans valeurs aberrantes)')

sns.boxplot(data=df, x="Expérience", y="PrêtApprouvé", orient='h', ax=ax[1, 0])
ax[1, 0].set_title('Boxplot : Expérience vs Prêt Approuvé')

# Affichage des graphiques
plt.tight_layout()
plt.show()

# Calcul des limites pour détecter les valeurs aberrantes
iqr = df["Expérience"].quantile(0.75) - df["Expérience"].quantile(0.25)
llim = df["Expérience"].quantile(0.25) - 1.5 * iqr
ulim = df["Expérience"].quantile(0.75) + 1.5 * iqr

# Impression des limites
print("llim :", llim, ",  ulim :", ulim)
# Out:
# llim : -15.0 ,  ulim : 49.0

# %%
# Création de la figure et des sous-graphes
fig, ax = plt.subplots(2, 2, figsize=(12, 6))

# Boxplots pour le Score de Risque et Prêt Approuvé
a1 = sns.boxplot(data=df, x="ScoreDeRisque", y="PrêtApprouvé", orient='h', showfliers=False, ax=ax[0, 1])
a1.set_title('Boxplot : Score de Risque vs Prêt Approuvé (sans valeurs aberrantes)')

a2 = sns.boxplot(data=df, x="ScoreDeRisque", y="PrêtApprouvé", orient='h', ax=ax[0, 0])
a2.set_title('Boxplot : Score de Risque vs Prêt Approuvé')

# Boxplots pour l'Ancienneté et Prêt Approuvé
a11 = sns.boxplot(data=df, x="Ancienneté", y="PrêtApprouvé", orient='h', showfliers=False, ax=ax[1, 1])
a11.set_title('Boxplot : Ancienneté vs Prêt Approuvé (sans valeurs aberrantes)')

a12 = sns.boxplot(data=df, x="Ancienneté", y="PrêtApprouvé", orient='h', ax=ax[1, 0])
a12.set_title('Boxplot : Ancienneté vs Prêt Approuvé')

# Ajustement de l'affichage des graphiques
plt.tight_layout()
plt.show()

# Suppression des étiquettes des axes pour a1 et a2
a1.set_xticklabels([])
a2.set_xlabel("")

# Calcul des limites pour détecter les valeurs aberrantes
iqr = df["ScoreDeRisque"].quantile(0.75) - df["ScoreDeRisque"].quantile(0.25)
llim = df["ScoreDeRisque"].quantile(0.25) - 1.5 * iqr
ulim = df["ScoreDeRisque"].quantile(0.75) + 1.5 * iqr

# Impression des limites
print("llim :", llim, ",  ulim :", ulim)
# Out:
# llim : 31.0 ,  ulim : 71.0

# %%
df[(df["ScoreDeRisque"]<=llim) | (df["ScoreDeRisque"]>=ulim)].describe()
# Out:
#               Age   RevenuAnnuel  ScoreDeCrédit  Expérience  MontantDuPrêt  \
# count  123.000000     123.000000     123.000000  123.000000     123.000000
# mean    40.130081   51259.959350     562.723577   17.918699   24564.593496
# std     12.261468   37314.547935      62.208573   12.092942   13699.820796
# min     18.000000   15000.000000     397.000000    0.000000    4044.000000
# 25%     32.000000   29769.000000     520.000000    9.000000   15428.500000
# 50%     39.000000   38962.000000     565.000000   16.000000   22313.000000
# 75%     47.000000   60695.500000     595.500000   25.500000   30976.000000
# max     77.000000  246538.000000     692.000000   58.000000   96375.000000
#
#        DuréeDuPrêt  NombreDeDépendants  PaiementsMensuelsDeDettes  \
# count   123.000000          123.000000                 123.000000
# mean     53.853659            1.544715                 446.325203
# std      25.863666            1.362568                 221.386965
# ...

# %%
df[(df["ScoreDeRisque"]>=llim) & (df["ScoreDeRisque"]<=ulim)].describe()
# Out:
#                 Age   RevenuAnnuel  ScoreDeCrédit    Expérience  \
# count  19906.000000   19906.000000   19906.000000  19906.000000
# mean      39.745454   59190.551894     571.643173     17.515975
# std       11.622124   40346.813068      50.912971     11.314404
# min       18.000000   15000.000000     343.000000      0.000000
# 25%       31.000000   31699.750000     540.000000      9.000000
# 50%       40.000000   48640.500000     578.000000     17.000000
# 75%       48.000000   74435.500000     609.000000     25.000000
# max       80.000000  485341.000000     712.000000     61.000000
#
#        MontantDuPrêt   DuréeDuPrêt  NombreDeDépendants  \
# count   19906.000000  19906.000000        19906.000000
# mean    24880.573596     54.063900            1.517181
# std     13423.546070     24.661558            1.386710
# min      3674.000000     12.000000            0.000000
# 25%     15575.750000     36.000000            0.000000
# ...

# %% [markdown]
# sns.pairplot(data=df)

# %%
df[df["ScoreDeRisque"]>=ulim].value_counts().sum()
# Out:
# 103

# %% [markdown]
# On constate que beaucoup de variables présentent des valeurs aberrantes. Leur traitement dépendera du model à utiliser.
# Ici il était question de vérifier la nature de ces outliers.

# %% [markdown]
# <a name="ANALYSE"></a>
# # **<h1 id="2" style="background-color:#F0EFEB;font-family:newtimeroman;font-size:150%;color:#28a745;text-align:center;border-radius:15px 15px;padding:7px;border:solid 3px #28a745;">ANALYSE</h1>**
#
# - Analyze des relationships entre variables

# %% [markdown]
# ## Step 2.  l'Exploration continue des données
#
# Le nombre de Prêt Approuvé et de  Prêt non Approuvé

# %%
# Le nombre de  Prêt Approuvé vs  Prêt non Approuvé

print(df.PrêtApprouvé.value_counts())
print()

# En percentages 

print(df.PrêtApprouvé.value_counts(normalize=True)*100)
# Out:
# PrêtApprouvé
# 0    15220
# 1     4780
# Name: count, dtype: int64
#
# PrêtApprouvé
# 0    76.1
# 1    23.9
# Name: proportion, dtype: float64

# %%
# Créez un graphique à barres pour visualiser les prêts approuvés et non approuvés
plt.figure(figsize=(6, 6))
ax = sns.countplot(data=df, x='PrêtApprouvé', color='green', width=0.4, dodge=False)  # Ajuste la largeur ici

# Ajustement des positions pour créer un espace entre les barres
for i, p in enumerate(ax.patches):
    p.set_width(0.4)  # Largeur de la barre
    p.set_x(p.get_x() )  # Décalage pour la distance

# Ajuster les ticks de l'axe x
plt.xticks([0, 1], ['Prêt Non Approuvé', 'Prêt Approuvé'])

# Supprimer la barre des ordonnées (axe y)
ax.spines['left'].set_visible(False)

# Calculer le total des prêts pour le pourcentage
total = len(df)

# Afficher les pourcentages au-dessus de chaque barre
for p in ax.patches:
    height = p.get_height()
    percentage = (height / total) * 100
    ax.text(p.get_x() + p.get_width() / 2, height, f'{percentage:.1f}%', 
            ha='center', va='bottom')

# Ajouter des labels et un titre
plt.xlabel('')
plt.ylabel('')
plt.title('Prêts Approuvés vs Non Approuvés')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
plt.yticks([])

# Afficher le graphique
plt.show()

# %% [markdown]
# La variable cible n'est pas équilibrer mais comme que ca dépasse les 80/20 donc ce n'est pas nécessaire de faire un rééchantillonnage. Néanmoins, nous y tiendrons compte au moment de déterminer les données pour le trainning, le test et la validation.

# %% [markdown]
# ## Visualisation

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['DateDeDemande', 'StatutDemploi', 'NiveauDEducation', 'StatutMarital',
#        'StatutDePropriété', 'ObjectifDuPrêt'],
#       dtype='object')

# %%
df.groupby(["PrêtApprouvé"])["ScoreDeRisque"].agg([np.mean, np.median])
# Out:
#                    mean  median
# PrêtApprouvé
# 0             54.106307    54.0
# 1             40.133389    40.0

# %%
df.groupby(["StatutMarital"])["ScoreDeRisque"].agg([np.mean, np.median])
# Out:
#                     mean  median
# StatutMarital
# Célibataire    50.889668    52.0
# Divorcé        50.521652    52.0
# Marié          50.735843    52.0
# Veuf/Veuve     51.037237    52.0

# %%
result = df.groupby(["StatutMarital"])["ScoreDeRisque"].agg([np.mean, np.median]).reset_index()

# Préparation des données pour l'histogramme
labels = result['StatutMarital']
mean_values = result['mean']
median_values = result['median']

# Création de l'histogramme
plt.figure(figsize=(8, 5))

# Barres pour la moyenne
bar_width = 0.25
x = np.arange(len(labels))

plt.bar(x - bar_width/2, mean_values, bar_width, label='Moyenne', color='lightblue')
plt.bar(x + bar_width/2, median_values, bar_width, label='Médiane', color='salmon')

# Ajout des étiquettes et du titre
plt.xlabel('Statut Marital')
plt.ylabel('Score de Risque')
plt.title('Moyennes et Médianes des Scores de Risque par Statut Marital')
plt.xticks(x, labels)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Les scores moyens varient légèrement entre les statuts maritaux, avec les veufs ayant le score moyen le plus élevé (51.04) et les divorcés le plus bas (50.52). Cela pourrait indiquer des nuances, mais les différences sont relativement faibles.
# Pour la médiane, les scores de risque sont constants à 52.0 pour tous les statuts. Cela suggère que, bien que les moyennes présentent des variations, la majorité des clients dans chaque catégorie se situent autour de la même valeur de risque.
#
# L'absence de variation significative dans les médianes pourrait indiquer que le statut marital pourrait être un prédicteur faible du niveau de risque du client. En effet, si la médiane est identique pour tous les groupes, cela signifie que le statut marital n'apporte pas une distinction claire en matière de risque.

# %%
df.head(3)
# Out:
#   DateDeDemande  Age  RevenuAnnuel  ScoreDeCrédit StatutDemploi  \
# 0    2018-01-01   45         39948            617       Employé
# 1    2018-01-02   38         39709            628       Employé
# 2    2018-01-03   47         40724            570       Employé
#
#   NiveauDEducation  Expérience  MontantDuPrêt  DuréeDuPrêt StatutMarital  \
# 0         Maîtrise          22          13152           48         Marié
# 1          Associé          15          26045           48   Célibataire
# 2          Licence          26          17627           36         Marié
#
#    NombreDeDépendants StatutDePropriété  PaiementsMensuelsDeDettes  \
# 0                   2      Propriétaire                        183
# 1                   1        Hypothèque                        496
# 2                   2          Location                        902
#
#    TauxDutilisationDesCartesDeCrédit  NombreDeLignesDeCréditOuvertes  \
# 0                           0.354418                               1
# ...

# %%
df.groupby(["NiveauDEducation"])["ScoreDeRisque"].agg([np.mean, np.median])
# Out:
#                        mean  median
# NiveauDEducation
# Associé           51.342588    52.0
# Doctorat          47.584486    48.0
# Licence           50.325140    51.0
# Lycée             52.214421    53.0
# Maîtrise          49.073049    50.0

# %%
result = df.groupby(["NiveauDEducation"])["ScoreDeRisque"].agg([np.mean, np.median]).reset_index()

# Préparation des données pour l'histogramme
labels = result['NiveauDEducation']
mean_values = result['mean']
median_values = result['median']

# Création de l'histogramme
plt.figure(figsize=(8, 5))

# Barres pour la moyenne
bar_width = 0.25
x = np.arange(len(labels))

plt.bar(x - bar_width/2, mean_values, bar_width, label='Moyenne', color='lightblue')
plt.bar(x + bar_width/2, median_values, bar_width, label='Médiane', color='salmon')

# Ajout des étiquettes et du titre
plt.xlabel('Education Level')
plt.ylabel('Score de Risque')
plt.title('Moyennes et Médianes des Scores de Risque par Education Level')
plt.xticks(x, labels)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Les scores moyens varient entre les niveaux d'éducation, avec le high school ayant le score le plus élevé(52.21) et le  doctorat le plus faible 47.58(). Cela pourrait indiquer des différences relativement importantes. Pour la médiane, les scores moyens de risques sont différents d'un niveau à l'autre dont le plus important est enregistre chez leniveau High School et le plus faible le niveau doctorat. Cela  suggère que la majorité des clients dans chaque catégorie se situent autour des valeurs différentes de risque.
#
# La variation significative dans les médianes pourrait indiquer que le statut marital pourrait être un bon prédicteur du niveau de risque du client.

# %%
#StatutDePropriété
df.groupby(["StatutDePropriété"])["ScoreDeRisque"].agg([np.mean, np.median])
# Out:
#                         mean  median
# StatutDePropriété
# Autre              51.089784    52.0
# Hypothèque         50.687769    52.0
# Location           50.814687    52.0
# Propriétaire       50.685018    52.0

# %% [markdown]
# Les scores moyens varient légèrement entre le statut de propriété du logement, avec les hypothèques immobilières et les propriétaires ayant les score moyens les plus faibles et les autrs le plus élevé.
#
# Pour la médiane, les scores de risque sont constants à 52.0 pour tous les statuts. Cela suggère que, bien que les moyennes présentent des variations, la majorité des clients dans chaque catégorie se situe autour de la même valeur de risque.
#
# L'absence de variation significative dans les médianes pourrait indiquer que le statut propriété du logement pourrait être un prédicteur faible du niveau de risque du client.

# %%
#StatutDemploi
df.groupby(["StatutDemploi"])["ScoreDeRisque"].agg([np.mean, np.median])
# Out:
#                            mean  median
# StatutDemploi
# Chômeur               53.947520    55.0
# Employé               50.351104    51.0
# Travailleur_Autonome  52.455944    54.0

# %% [markdown]
# La moyenne des scores de risques varie d'un statut d'emploi à l'autre avec les chomeurs ayant un risque plus élevé (53.94) et les employés le scores le plus faible (50.35). De meme que auniveau des médiane on note également une différence entre les niveaux. Cela suggère que la majorité des clients dans chaque catégorie se situe dans des niveaux de risque différent. Cette variation au niveau des médianes pourrait indiquer que le statut de l'emploi pourrait etre un bon prédicteur du niveau de risque du client.

# %%
#ObjectifDuPrêt
df.groupby(["ObjectifDuPrêt"])["ScoreDeRisque"].agg([np.mean, np.median])
# Out:
#                               mean  median
# ObjectifDuPrêt
# Auto                     50.643183    52.0
# Autre                    51.092124    52.0
# Consolidation de dettes  50.946330    52.0
# Maison                   50.721215    52.0
# Éducation                50.505253    51.0

# %% [markdown]
# Les catégories de prêts avec des scores moyens et médians similaires à 52.0 (comme Auto, Debt Consolidation, et Home) montrent un profil de risque relativement similaire, tandis que la catégorie Éducation pourrait nécessiter une attention particulière en raison de son score moyen plus bas.
# Cela pourrait indiquer que cette variable serait un bon indicateur pour déterminer le niveau de risque. De meme qu'une attention particulière doit etre portée sur cette variable lors de la modélisation
# ( *distinguer éducation aux autres* )

# %%
df.columns
# Out:
# Index(['DateDeDemande', 'Age', 'RevenuAnnuel', 'ScoreDeCrédit',
#        'StatutDemploi', 'NiveauDEducation', 'Expérience', 'MontantDuPrêt',
#        'DuréeDuPrêt', 'StatutMarital', 'NombreDeDépendants',
#        'StatutDePropriété', 'PaiementsMensuelsDeDettes',
#        'TauxDutilisationDesCartesDeCrédit', 'NombreDeLignesDeCréditOuvertes',
#        'NombreDeDemandesDeCrédit', 'RatioDettesRevenus',
#        'HistoriqueDeFaillite', 'ObjectifDuPrêt', 'DéfautsPrécédentsSurPrêts',
#        'HistoriqueDesPaiements', 'DuréeDeHistoriqueDeCrédit',
#        'SoldeDuCompteÉpargne', 'SoldeDuCompteCourant', 'TotalDesActifs',
#        'TotalDesPassifs', 'RevenuMensuel', 'HistoriqueDesPaiementsDesFactures',
#        'Ancienneté', 'ValeurNette', 'TauxDintérêtDeBase', 'TauxDintérêt',
#        'PaiementMensuelDuPrêt', 'RatioTotalDettesRevenus', 'PrêtApprouvé',
#        'ScoreDeRisque'],
#       dtype='object')

# %% [markdown]
# *Conclusion(object)*
# 'StatutMarital', 'StatutDePropriété', : pourraient etre non significatives\
# 'StatutDemploi', 'ObjectifDuPrêt','NiveauDEducation' : pourraient etre significatives

# %%
df.head(3)
# Out:
#   DateDeDemande  Age  RevenuAnnuel  ScoreDeCrédit StatutDemploi  \
# 0    2018-01-01   45         39948            617       Employé
# 1    2018-01-02   38         39709            628       Employé
# 2    2018-01-03   47         40724            570       Employé
#
#   NiveauDEducation  Expérience  MontantDuPrêt  DuréeDuPrêt StatutMarital  \
# 0         Maîtrise          22          13152           48         Marié
# 1          Associé          15          26045           48   Célibataire
# 2          Licence          26          17627           36         Marié
#
#    NombreDeDépendants StatutDePropriété  PaiementsMensuelsDeDettes  \
# 0                   2      Propriétaire                        183
# 1                   1        Hypothèque                        496
# 2                   2          Location                        902
#
#    TauxDutilisationDesCartesDeCrédit  NombreDeLignesDeCréditOuvertes  \
# 0                           0.354418                               1
# ...

# %%
df.groupby(["PrêtApprouvé"])["DuréeDeHistoriqueDeCrédit"].agg([np.mean, np.median])
# Out:
#                    mean  median
# PrêtApprouvé
# 0             14.460250    14.0
# 1             16.539958    17.0

# %%
df1=df.drop(columns=['DateDeDemande', 'DuréeDuPrêt', 'NombreDeDépendants',
                     'Ancienneté', 'HistoriqueDesPaiementsDesFactures', 'SoldeDuCompteCourant', 'SoldeDuCompteÉpargne',
                     'HistoriqueDesPaiements', 'DéfautsPrécédentsSurPrêts', 'HistoriqueDeFaillite',
                     'RatioDettesRevenus', 'NombreDeDemandesDeCrédit',
                     'NombreDeLignesDeCréditOuvertes', 'TauxDutilisationDesCartesDeCrédit',
                     'NombreDeDépendants', 'DuréeDuPrêt', 'NombreDeLignesDeCréditOuvertes',
                     'NombreDeDemandesDeCrédit',"PrêtApprouvé"])
df1.head(3)
# Out:
#    Age  RevenuAnnuel  ScoreDeCrédit StatutDemploi NiveauDEducation  \
# 0   45         39948            617       Employé         Maîtrise
# 1   38         39709            628       Employé          Associé
# 2   47         40724            570       Employé          Licence
#
#    Expérience  MontantDuPrêt StatutMarital StatutDePropriété  \
# 0          22          13152         Marié      Propriétaire
# 1          15          26045   Célibataire        Hypothèque
# 2          26          17627         Marié          Location
#
#    PaiementsMensuelsDeDettes           ObjectifDuPrêt  \
# 0                        183                   Maison
# 1                        496  Consolidation de dettes
# 2                        902                Éducation
#
#    DuréeDeHistoriqueDeCrédit  TotalDesActifs  TotalDesPassifs  RevenuMensuel  \
# 0                          9          146111            19183    3329.000000
# ...

# %%
#Age vs Expérience
df.groupby(["PrêtApprouvé"])["Age"].agg([np.mean, np.median])
# Out:
#                    mean  median
# PrêtApprouvé
# 0             38.834034    39.0
# 1             42.677406    42.0

# %%
#Age vs Expérience
df.groupby(["PrêtApprouvé"])["Expérience"].agg([np.mean, np.median])
# Out:
#                    mean  median
# PrêtApprouvé
# 0             16.630092    16.0
# 1             20.365063    20.0

# %%
#Age vs Expérience
df.groupby(["PrêtApprouvé"])["Age"].agg([np.mean, np.median])
# Out:
#                    mean  median
# PrêtApprouvé
# 0             38.834034    39.0
# 1             42.677406    42.0

# %%
sns.lmplot(data=df, y='Expérience',x='ScoreDeRisque',hue='PrêtApprouvé')

# %% [markdown]
# L'age et l'expérience sont fortement corrélés. Nous allons garder la variable "Expérience".

# %%
#RevenuMensuel vs RevenuAnnuel
sns.lmplot(data=df, y='RevenuMensuel',x='ScoreDeRisque', hue='PrêtApprouvé')

# %%
#RevenuMensuel vs RevenuAnnuel
sns.lmplot(data=df, y='RevenuAnnuel',x='ScoreDeRisque', hue='PrêtApprouvé')

# %% [markdown]
# Le revenu mensuel et le revenu annuel sont fortement corrélés. Nous allons garder la variable "RevenuMensuel" car il y a moins  de valeur aberrantes sur cette variable.

# %%
#PaiementMensuelDuPrêts vs #MonthlyDeptpayment 
df.groupby(["PrêtApprouvé"])["PaiementsMensuelsDeDettes"].agg([np.mean, np.median])
# Out:
#                     mean  median
# PrêtApprouvé
# 0             463.783180   409.0
# 1             424.074059   380.0

# %%
df.groupby(["PrêtApprouvé"])["PaiementMensuelDuPrêt"].agg([np.mean, np.median])
# Out:
#                     mean      median
# PrêtApprouvé
# 0             981.268113  791.221206
# 1             689.799237  576.034806

# %% [markdown]
# On va choisir 'PaiementMensuelDuPrêt'

# %%
df.groupby(['PrêtApprouvé'])['DuréeDuPrêt'].agg([np.mean, np.median])
# Out:
#                    mean  median
# PrêtApprouvé
# 0             55.363995    48.0
# 1             49.895397    48.0

# %% [markdown]
# La médiane n'est pas différente ce qui veux dire il n'existe pas de différences significatives entre différente catégories. Donc la 'DuréeDuPrêt' ne sera pas choisie.

# %%
#Les différentes variables retenues

df[['ScoreDeCrédit', 'StatutDemploi',
    'NiveauDEducation', 'Expérience', 'MontantDuPrêt', 'StatutMarital',
    'StatutDePropriété','ObjectifDuPrêt',
    'DuréeDeHistoriqueDeCrédit', 'RevenuMensuel','TauxDintérêt', 'PaiementMensuelDuPrêt',
    'RatioTotalDettesRevenus', 'PrêtApprouvé', 'ScoreDeRisque']]
# Out:
#        ScoreDeCrédit StatutDemploi NiveauDEducation  Expérience  \
# 0                617       Employé         Maîtrise          22
# 1                628       Employé          Associé          15
# 2                570       Employé          Licence          26
# 3                545       Employé            Lycée          34
# 4                594       Employé          Associé          17
# ...              ...           ...              ...         ...
# 19995            587       Employé            Lycée          19
# 19996            567       Employé          Associé          33
# 19997            645       Employé          Licence          20
# 19998            560       Employé            Lycée          36
# 19999            574       Employé          Associé           0
#
#        MontantDuPrêt StatutMarital StatutDePropriété           ObjectifDuPrêt  \
# 0              13152         Marié      Propriétaire                   Maison
# ...

# %%
# On affecte les variables retenue
df1=df[['ScoreDeCrédit', 'StatutDemploi',
    'NiveauDEducation', 'Expérience', 'MontantDuPrêt', 'StatutMarital',
    'StatutDePropriété','ObjectifDuPrêt',
    'DuréeDeHistoriqueDeCrédit', 'RevenuMensuel','TauxDintérêt', 'PaiementMensuelDuPrêt',
    'RatioTotalDettesRevenus', "PrêtApprouvé"]]

df1.head(3)
# Out:
#    ScoreDeCrédit StatutDemploi NiveauDEducation  Expérience  MontantDuPrêt  \
# 0            617       Employé         Maîtrise          22          13152
# 1            628       Employé          Associé          15          26045
# 2            570       Employé          Licence          26          17627
#
#   StatutMarital StatutDePropriété           ObjectifDuPrêt  \
# 0         Marié      Propriétaire                   Maison
# 1   Célibataire        Hypothèque  Consolidation de dettes
# 2         Marié          Location                Éducation
#
#    DuréeDeHistoriqueDeCrédit  RevenuMensuel  TauxDintérêt  \
# 0                          9    3329.000000      0.227590
# 1                          9    3309.083333      0.201077
# 2                         22    3393.666667      0.212548
#
#    PaiementMensuelDuPrêt  RatioTotalDettesRevenus  PrêtApprouvé
# 0             419.805992                 0.181077             0
# ...

# %%
df1['ScoreRisque']=df.ScoreDeRisque.apply(lambda x : 'Faible' if x <46 else 'Elevé' if x >=56 else 'Moyen')

# %%
df1['ScoreRisque'].value_counts()
# Out:
# ScoreRisque
# Moyen     9866
# Elevé     5253
# Faible    4881
# Name: count, dtype: int64

# %%
df1['ScoreDeRisque']=df['ScoreDeRisque']

# %%
df1[df1['ScoreDeRisque']>=50]['ScoreRisque'].unique()
# Out:
# array(['Moyen', 'Elevé'], dtype=object)

# %%
df1['ScoreRisque'] = (df1['ScoreRisque'].astype('category').cat.set_categories(['Faible', 'Moyen', 'Elevé']).cat.codes)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ScoreDeCrédit              20000 non-null  int64
#  1   StatutDemploi              20000 non-null  object
#  2   NiveauDEducation           20000 non-null  object
#  3   Expérience                 20000 non-null  int64
#  4   MontantDuPrêt              20000 non-null  int64
#  5   StatutMarital              20000 non-null  object
#  6   StatutDePropriété          20000 non-null  object
#  7   ObjectifDuPrêt             20000 non-null  object
#  8   DuréeDeHistoriqueDeCrédit  20000 non-null  int64
#  9   RevenuMensuel              20000 non-null  float64
#  10  TauxDintérêt               20000 non-null  float64
#  11  PaiementMensuelDuPrêt      20000 non-null  float64
#  12  RatioTotalDettesRevenus    20000 non-null  float64
# ...

# %%
# Carte thermique (heatmap) des corrélations entre les variables numériques de df1
plt.figure(figsize=(12, 8))
sns.heatmap(df1.select_dtypes(include=['float64', 'int64']).corr(), annot=True, cmap="crest")
plt.title('Carte Thermique des Corrélations entre Variables Numériques retenues')
plt.show()

# %% [markdown]
# La carte de corrélation confirme que le montant du pret, le paiement mensuel et le ratio dette sont corrélés positivement. L'approbation du pret est corrélée positive au revenu mensuel et négativement au score de risque, au ratio de dette et au taux d'interet.

# %% [markdown]
# ### Insights

# %% [markdown]
# Ces observations mettent en lumière les relations clés entre les variables financières, soulignant l'importance de la gestion du niveau d'endettement et du profil de crédit pour l'approbation des prêts. Une compréhension approfondie de ces corrélations peut aider à mieux prédire les décisions d'approbation et à orienter les stratégies des emprunteurs et des prêteurs.

# %% [markdown]
# <a name="MODELISATION"></a>
# # **<h1 id="3" style="background-color:#F0EFEB;font-family:newtimeroman;font-size:150%;color:#28a745;text-align:center;border-radius:15px 15px;padding:7px;border:solid 3px #28a745;">MODELISATION</h1>**

# %% [markdown]
# ## Step 3. Modélisation

# %% [markdown]
# L'objectif est de construire un modèle pour prédire les approbation des prets, dont la variable de sortie est une catégorielle à deux modalités. Il s'agit donc d'une opération de classification. Pour la variable de sortie, 1 représente que le pret est approuvé et zéro le cas contraire.

# %% [markdown]
# Ainsi, nous allons utiliser 5 modèles de machine learning pour déterminer le plus performant. Entre autres nous avons le modèle de DecisionTreeClassifier, RandomForestClassifier, GradientBoostingClassifier, CatBoostClassifier et le XGBClassifier.

# %% [markdown]
# Envant de classer les données en données d'entrainement, de test et de validation. Nous allons transformer les variables catégorielles en variables numériques.

# %%
# Supprime la colonne 'PrêtApprouvé' de df1 et affiche les informations de la nouvelle DataFrame df1_enc
df1_enc = df1.drop(['PrêtApprouvé', 'ScoreDeRisque'], axis=1)
df1_enc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ScoreDeCrédit              20000 non-null  int64
#  1   StatutDemploi              20000 non-null  object
#  2   NiveauDEducation           20000 non-null  object
#  3   Expérience                 20000 non-null  int64
#  4   MontantDuPrêt              20000 non-null  int64
#  5   StatutMarital              20000 non-null  object
#  6   StatutDePropriété          20000 non-null  object
#  7   ObjectifDuPrêt             20000 non-null  object
#  8   DuréeDeHistoriqueDeCrédit  20000 non-null  int64
#  9   RevenuMensuel              20000 non-null  float64
#  10  TauxDintérêt               20000 non-null  float64
#  11  PaiementMensuelDuPrêt      20000 non-null  float64
#  12  RatioTotalDettesRevenus    20000 non-null  float64
# ...

# %%
# Convertit les variables catégorielles de df1_enc en variables indicatrices, en supprimant la première colonne pour éviter la multicolinéarité
X = pd.get_dummies(df1_enc, drop_first=True)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 25 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   ScoreDeCrédit                           20000 non-null  int64
#  1   Expérience                              20000 non-null  int64
#  2   MontantDuPrêt                           20000 non-null  int64
#  3   DuréeDeHistoriqueDeCrédit               20000 non-null  int64
#  4   RevenuMensuel                           20000 non-null  float64
#  5   TauxDintérêt                            20000 non-null  float64
#  6   PaiementMensuelDuPrêt                   20000 non-null  float64
#  7   RatioTotalDettesRevenus                 20000 non-null  float64
#  8   ScoreRisque                             20000 non-null  int8
#  9   StatutDemploi_Employé                   20000 non-null  bool
# ...

# %%
# La variable cible
y=df1['PrêtApprouvé']
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: PrêtApprouvé, dtype: int64

# %%
# Séparation des données en ensembles d'entraînement et de test
X_train, X_tr, y_train, y_tr = train_test_split(X, y, test_size=0.4, random_state=42)

# Séparation de l'ensemble de test en ensembles de validation et de test
X_val, X_test, y_val, y_test = train_test_split(X_tr, y_tr, test_size=0.5, random_state=42)

# Affiche les dimensions des ensembles
X_train.shape, X_test.shape, X_val.shape, y_train.shape, y_test.shape, y_val.shape
# Out:
# ((12000, 25), (4000, 25), (4000, 25), (12000,), (4000,), (4000,))

# %% [markdown]
# DecisionTreeClassifier, RandomForestClassifier, GradientBoostingClassifier, CatBoostClassifier et le XGBClassifier

# %%
# Initialiser les classificateurs avec une complexité modérée
cls1 = CatBoostClassifier(logging_level='Silent', n_estimators=10)
cls2 = DecisionTreeClassifier()
cls3 = RandomForestClassifier(n_estimators=10)
cls4 = GradientBoostingClassifier(n_estimators=10)
cls5 = LogisticRegression(random_state=0)

# Entraîner les classificateurs
cls1.fit(X_train, y_train)
cls2.fit(X_train, y_train)
cls3.fit(X_train, y_train)
cls4.fit(X_train, y_train)
cls5.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %% [markdown]
# ## Step 4. Resultats et Evaluation

# %%
# Prédire results par modèle
pred1 = cls1.predict(X_test)
pred2 = cls2.predict(X_test)
pred3 = cls3.predict(X_test)
pred4 = cls4.predict(X_test)
pred5 = cls5.predict(X_test)

# %%
# Calculer l'accuracy pour chaque classificateur
acc_values = [
    accuracy_score(y_test, pred1),
    accuracy_score(y_test, pred2),
    accuracy_score(y_test, pred3),
    accuracy_score(y_test, pred4),
    accuracy_score(y_test, pred5),
]

classifier_names = [
    'CatBoostClassifier',
    'DecisionTreeClassifier',
    'RandomForestClassifier',
    'GradientBoostingClassifier',
    'LogisticRegressionClassifier', 
]

# Trier les valeurs d'accuracy par ordre décroissant (de haut en bas)
acc_sorted_indices = np.argsort(acc_values)[::-1]
acc_values_sorted = np.array(acc_values)[acc_sorted_indices]
classifier_names_acc_sorted = np.array(classifier_names)[acc_sorted_indices]

# Créer une figure avec un seul sous-graphe
plt.figure(figsize=(9, 2))

# Tracer les valeurs d'accuracy (de haut en bas)
plt.barh(classifier_names_acc_sorted, acc_values_sorted, color='green')
plt.title('Accuracy of Classifiers (High to Low)')
plt.xlabel('Accuracy')
plt.xlim(0, 1)  # Supposant que l'accuracy varie entre 0 et 1
plt.gca().invert_yaxis()  # Meilleure performance en haut

# Afficher le graphique
plt.tight_layout()
plt.show()

# %% [markdown]
# Les modèles ont une très bonne performance, car chacun affiche une bonne accuracy (precision). Il semble que le Catboost présente la meilleure performance. Evaluons la courbe de auc.

# %%
y_true = y_test
# Calcul des courbes ROC et AUC
fpr1, tpr1, _ = roc_curve(y_true, pred1)  
roc_auc1 = auc(fpr1, tpr1)

fpr2, tpr2, _ = roc_curve(y_true, pred2)  
roc_auc2 = auc(fpr2, tpr2)

fpr3, tpr3, _ = roc_curve(y_true, pred3)  
roc_auc3 = auc(fpr3, tpr3)

fpr4, tpr4, _ = roc_curve(y_true, pred4)  
roc_auc4 = auc(fpr4, tpr4)

fpr5, tpr5, _ = roc_curve(y_true, pred5)  
roc_auc5 = auc(fpr5, tpr5)



# Tracer les courbes ROC
plt.figure(figsize=(10, 8))

# Courbe ROC pour chaque prédiction
plt.plot(fpr1, tpr1, color='green', lw=2, label='ROC curve (CatBoost Classifier = {:.4f})'.format(roc_auc1))
plt.plot(fpr2, tpr2, color='blue', lw=2, label='ROC curve (DecisionTree Classifier = {:.4f})'.format(roc_auc2))
plt.plot(fpr3, tpr3, color='orange', lw=2, label='ROC curve (RandomForest Classifier = {:.4f})'.format(roc_auc3))
plt.plot(fpr4, tpr4, color='red', lw=2, label='ROC curve (GradientBoosting Classifier = {:.4f})'.format(roc_auc4))
plt.plot(fpr5, tpr5, color='indigo', lw=2, label='ROC curve (LogisticRegression Classifier = {:.4f})'.format(roc_auc5))


# Ligne diagonale
plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')

# Configurations des axes
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')

# Afficher le graphique
plt.show()

# %% [markdown]
# Effectivement ce résultat est confirmé par la courbe. Donc le modèle Catboost Classier enregistre la meilleure performance. Cependant, nous allons les modèles avec les données de tests.

# %%
# Supposons que test_pred et y_test sont déjà définis
y_true = y_test
y_pred = pred1  

# Calculer les métriques de classification
metrics = pd.DataFrame({
    'Metric': ['Accuracy', 'Precision', 'Recall', 'F1 Score'],
    'Score': [
        accuracy_score(y_true, y_pred),
        precision_score(y_true, y_pred),
        recall_score(y_true, y_pred),
        f1_score(y_true, y_pred)
    ]
})

# Imprimer les métriques
print(metrics.to_string(index=False, float_format='%.4f'))

# Visualisation des métriques
plt.figure(figsize=(8, 3))
bar_plot = sns.barplot(x='Score', y='Metric', data=metrics, palette='Greens')
plt.title('CatBoost Model Performance Metrics')
plt.xlabel('Score')
plt.ylabel('Metrics')
plt.xlim(0, 1)

# Afficher les valeurs à l'intérieur des barres
for index, row in metrics.iterrows():
    bar_plot.text(row['Score'] + 0.04 , index, f'{ row["Score"]  :.4f}', color='black', ha='left', va='center')

# Enlever le cadre de l'axe des abscisses
bar_plot.spines['right'].set_visible(False)
bar_plot.spines['top'].set_visible(False)
bar_plot.spines['left'].set_visible(False)

plt.show()
# Out:
#    Metric  Score
#  Accuracy 0.9838
# Precision 0.9600
#    Recall 0.9730
#  F1 Score 0.9665

# %%
# Supposons que test_pred et y_test sont déjà définis
y_true = y_test
y_pred = pred2  

# Calculer les métriques de classification
metrics = pd.DataFrame({
    'Metric': ['Accuracy', 'Precision', 'Recall', 'F1 Score'],
    'Score': [
        accuracy_score(y_true, y_pred),
        precision_score(y_true, y_pred),
        recall_score(y_true, y_pred),
        f1_score(y_true, y_pred)
    ]
})

# Imprimer les métriques
print(metrics.to_string(index=False, float_format='%.4f'))

# Visualisation des métriques
plt.figure(figsize=(8, 3))
bar_plot = sns.barplot(x='Score', y='Metric', data=metrics, palette='Greens')
plt.title('DecisionTree Model Performance Metrics')
plt.xlabel('Score')
plt.ylabel('Metrics')
plt.xlim(0, 1)

# Afficher les valeurs à l'intérieur des barres
for index, row in metrics.iterrows():
    bar_plot.text(row['Score'] + 0.04 , index, f'{ row["Score"]  :.4f}', color='black', ha='left', va='center')

# Enlever le cadre de l'axe des abscisses
bar_plot.spines['right'].set_visible(False)
bar_plot.spines['top'].set_visible(False)
bar_plot.spines['left'].set_visible(False)

plt.show()
# Out:
#    Metric  Score
#  Accuracy 0.9680
# Precision 0.9291
#    Recall 0.9387
#  F1 Score 0.9339

# %%
# Supposons que test_pred et y_test sont déjà définis
y_true = y_test
y_pred = pred3  

# Calculer les métriques de classification
metrics = pd.DataFrame({
    'Metric': ['Accuracy', 'Precision', 'Recall', 'F1 Score'],
    'Score': [
        accuracy_score(y_true, y_pred),
        precision_score(y_true, y_pred),
        recall_score(y_true, y_pred),
        f1_score(y_true, y_pred)
    ]
})

# Imprimer les métriques
print(metrics.to_string(index=False, float_format='%.4f'))

# Visualisation des métriques
plt.figure(figsize=(8, 3))
bar_plot = sns.barplot(x='Score', y='Metric', data=metrics, palette='Greens')
plt.title('RandomForest  Model Performance Metrics')
plt.xlabel('Score')
plt.ylabel('Metrics')
plt.xlim(0, 1)

# Afficher les valeurs à l'intérieur des barres
for index, row in metrics.iterrows():
    bar_plot.text(row['Score'] + 0.04 , index, f'{ row["Score"]  :.4f}', color='black', ha='left', va='center')

# Enlever le cadre de l'axe des abscisses
bar_plot.spines['right'].set_visible(False)
bar_plot.spines['top'].set_visible(False)
bar_plot.spines['left'].set_visible(False)

plt.show()
# Out:
#    Metric  Score
#  Accuracy 0.9792
# Precision 0.9603
#    Recall 0.9533
#  F1 Score 0.9567

# %%
# Supposons que test_pred et y_test sont déjà définis
y_true = y_test
y_pred = pred4  

# Calculer les métriques de classification
metrics = pd.DataFrame({
    'Metric': ['Accuracy', 'Precision', 'Recall', 'F1 Score'],
    'Score': [
        accuracy_score(y_true, y_pred),
        precision_score(y_true, y_pred),
        recall_score(y_true, y_pred),
        f1_score(y_true, y_pred)
    ]
})

# Imprimer les métriques
print(metrics.to_string(index=False, float_format='%.4f'))

# Visualisation des métriques
plt.figure(figsize=(8, 3))
bar_plot = sns.barplot(x='Score', y='Metric', data=metrics, palette='Greens')
plt.title('GRadientBoosting Model Performance Metrics')
plt.xlabel('Score')
plt.ylabel('Metrics')
plt.xlim(0, 1)

# Afficher les valeurs à l'intérieur des barres
for index, row in metrics.iterrows():
    bar_plot.text(row['Score'] + 0.04 , index, f'{ row["Score"]  :.4f}', color='black', ha='left', va='center')

# Enlever le cadre de l'axe des abscisses
bar_plot.spines['right'].set_visible(False)
bar_plot.spines['top'].set_visible(False)
bar_plot.spines['left'].set_visible(False)

plt.show()
# Out:
#    Metric  Score
#  Accuracy 0.9732
# Precision 0.9544
#    Recall 0.9335
#  F1 Score 0.9438

# %%
# Supposons que test_pred et y_test sont déjà définis
y_true = y_test
y_pred = pred5  

# Calculer les métriques de classification
metrics = pd.DataFrame({
    'Metric': ['Accuracy', 'Precision', 'Recall', 'F1 Score'],
    'Score': [
        accuracy_score(y_true, y_pred),
        precision_score(y_true, y_pred),
        recall_score(y_true, y_pred),
        f1_score(y_true, y_pred)
    ]
})

# Imprimer les métriques
print(metrics.to_string(index=False, float_format='%.4f'))

# Visualisation des métriques
plt.figure(figsize=(8, 3))
bar_plot = sns.barplot(x='Score', y='Metric', data=metrics, palette='Greens')
plt.title('Logistic Regression Model Performance Metrics')
plt.xlabel('Score')
plt.ylabel('Metrics')
plt.xlim(0, 1)

# Afficher les valeurs à l'intérieur des barres
for index, row in metrics.iterrows():
    bar_plot.text(row['Score'] + 0.04 , index, f'{ row["Score"]  :.4f}', color='black', ha='left', va='center')

# Enlever le cadre de l'axe des abscisses
bar_plot.spines['right'].set_visible(False)
bar_plot.spines['top'].set_visible(False)
bar_plot.spines['left'].set_visible(False)

plt.show()
# Out:
#    Metric  Score
#  Accuracy 0.8822
# Precision 0.7908
#    Recall 0.6947
#  F1 Score 0.7396

# %% [markdown]
# Avec les données de test, le CatBoost affiche la meilleure performance. Ainsi nous allons valider le modèle avec les données de validation.

# %%
#  test_pred et y_test 
y_true = y_test
y_pred = pred1  

# Calculer les métriques de classification
metrics = pd.DataFrame({
    'Metric': ['Accuracy', 'Precision', 'Recall', 'F1 Score'],
    'Score': [
        accuracy_score(y_true, y_pred),
        precision_score(y_true, y_pred),
        recall_score(y_true, y_pred),
        f1_score(y_true, y_pred)
    ]
})

# Imprimer les métriques
print(metrics.to_string(index=False, float_format='%.4f'))

# Visualisation des métriques
plt.figure(figsize=(8, 3))
bar_plot = sns.barplot(x='Score', y='Metric', data=metrics, palette='Greens')
plt.title('CatBoost Model Performance Metrics')
plt.xlabel('Score')
plt.ylabel('Metrics')
plt.xlim(0, 1)

# Afficher les valeurs à l'intérieur des barres
for index, row in metrics.iterrows():
    bar_plot.text(row['Score'] + 0.04 , index, f'{ row["Score"]  :.4f}', color='black', ha='left', va='center')

# Enlever le cadre de l'axe des abscisses
bar_plot.spines['right'].set_visible(False)
bar_plot.spines['top'].set_visible(False)
bar_plot.spines['left'].set_visible(False)

plt.show()

# Matrice de confusion
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', cbar=False, 
            xticklabels=['Predicted Neg', 'Predicted Pos'], 
            yticklabels=['True Neg', 'True Pos'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Courbe ROC
fpr, tpr, _ = roc_curve(y_true, pred1)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='green', lw=2, label='ROC curve (area = {:.4f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()
# Out:
#    Metric  Score
#  Accuracy 0.9838
# Precision 0.9600
#    Recall 0.9730
#  F1 Score 0.9665

# %% [markdown]
# ## Validation du modèle

# %%
cls1_val_pred = cls1.predict(X_val)
cm1 = confusion_matrix(y_val, cls1_val_pred)

plt.figure(figsize=(4, 4))
sns.heatmap(cm1, annot=True, fmt='d', cmap='Greens', cbar=False, 
            xticklabels=['Non Approuvé', 'Approuvé'], 
            yticklabels=['Non Approuvé', 'Approuvé'])
plt.title('Confusion Matrix (Cat Boost)')
plt.xlabel('Prédiction')
plt.ylabel('Réelle')
plt.show()

# %%
cls5_val_pred = cls5.predict(X_val)
cm5 = confusion_matrix(y_val, cls5_val_pred)

plt.figure(figsize=(4, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', cbar=False, 
            xticklabels=['Non Approuvé', 'Approuvé'], 
            yticklabels=['Non Approuvé', 'Approuvé'])
plt.title('Confusion Matrix (Logistic Regression)')
plt.xlabel('Prédiction')
plt.ylabel('Réelle')

# %% [markdown]
# Ces résultats (faibles taux de faux positifs et de faux négatifs) indiquent que le modèle fonctionne très bien avec un très faible taux d'erreurs.

# %%
# matrices de confusion

fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Heatmap pour la régression logistique
sns.heatmap(cm5, annot=True, fmt='d', cmap='Greens', cbar=False, 
            xticklabels=['Non Approuvé', 'Approuvé'], 
            yticklabels=['Non Approuvé', 'Approuvé'], ax=ax[0])
ax[0].set_title('Régression Logistique')
ax[0].set_ylabel('Observations')  # Ajout du label pour l'axe des y

# Heatmap pour CatBoost
sns.heatmap(cm1, annot=True, fmt='d', cmap='Blues', cbar=False, 
            xticklabels=['Non Approuvé', 'Approuvé'], 
            yticklabels=['Non Approuvé', 'Approuvé'], ax=ax[1])
ax[1].set_title('CatBoost')
#ax[1].set_ylabel('Réelle')  # Ajout du label pour l'axe des y

# Titre général pour la figure
fig.suptitle('Matrices de Confusion Régression Logistique vs CatBoost', fontsize=13)

# Ajouter un label commun pour l'axe des x
fig.text(0.5, -0.02, 'Prédictions', ha='center', fontsize=12)

plt.tight_layout(rect=[0, 0, 1, 0.96])  # Ajuste l'espacement pour le titre
plt.show()

# %%
cls1_val_pred = cls1.predict(X_val)
cm = confusion_matrix(y_val, cls1_val_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', cbar=False, 
            xticklabels=['Prédiction Neg', 'Prédiction Pos'], 
            yticklabels=['Non Approuvé', 'Approuvé'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
# Get feature importances
feat_impt = cls1.feature_importances_

# Get indices of top 10 features
ind = np.argpartition(cls1.feature_importances_, -10)[-12:]

# Get column labels of top 10 features 
feat = X.columns[ind]

# Filter `feat_impt` to consist of top 10 feature importances
feat_impt = feat_impt[ind]

y_df = pd.DataFrame({"Feature":feat,"Importance":feat_impt})
y_sort_df = y_df.sort_values("Importance")
fig = plt.figure()
ax1 = fig.add_subplot(111)

y_sort_df.plot(kind='barh',ax=ax1,x="Feature",y="Importance", color='green')

ax1.set_title("L'importance des variables sur les prêts non approuvés", fontsize=12)
ax1.set_ylabel("variable")
ax1.set_xlabel("Importance")

plt.show()

# %% [markdown]
# Le barplot ci-dessus montre que dans ce modèle de Catboost,  le score de risque, le ratio total dettes revenus, le taux d'intérêt, le revenu mensuel, le score de crédit
#  et le montant du prêt  ont la plus haute impacte dans cet orde. Ces variables sont les plus significatives pour la prédiction des prêts approuvés.

# %% [markdown]
# <a name="c_r"></a>
# # **<h1 id="4" style="background-color:#F0EFEB;font-family:newtimeroman;font-size:150%;color:#28a745;text-align:center;border-radius:15px 15px;padding:7px;border:solid 3px #28a745;">Conclusion et Recommandations</h1>**

# %% [markdown]
# Les résultats montrent que les variables telles que: le score de risque, le ratio total dettes revenus, le taux d'intérêt, le score de crédit et le revenu mensuel jouent un rôle important dans l'approbation des prêts. Ainsi certaines recommandations ont été proposées:
#
# * **Score de Risque** :
#    - **Utiliser des outils d'évaluation améliorés** : Implémentez des systèmes d'évaluation pour mieux prédire le score de risque des emprunteurs. Cela pourrait inclure des modèles prédictifs avancés ou des techniques d'analyse de données pour identifier les facteurs de risque.
#    - **Éducation des clients** : Fournissez des ressources éducatives pour aider les emprunteurs à comprendre comment leur score de risque est calculé et comment ils peuvent l'améliorer.
#
# * **Ratio Total Dettes/Revenus** :
#    - **Établir des seuils de référence** : Définissez des seuils de ratio dettes/revenus acceptables pour approuver les prêts et éviter le surendettement.
#    - **Conseils financiers** : Proposez des conseils aux emprunteurs sur la gestion de leurs dettes, les aidant à maintenir un ratio favorable.
# * **Taux d'Intérêt** :
#    - **Offrir des options de taux variables** : Considérez la possibilité d'offrir des taux d'intérêt variables basés sur le profil de risque de l'emprunteur. Cela peut attirer des emprunteurs avec de bons antécédents de crédit.
#    - **Transparence des conditions** : Assurer à ce que les conditions de taux d'intérêt soient clairement communiquées aux clients pour éviter toute confusion lors de l'approbation des prêts.
#
# * **Score de Crédit** :
#    - **Programmes de fidélité** : Mettez en place des programmes de fidélité ou de récompense pour les clients qui maintiennent un bon score de crédit, ce qui peut encourager un comportement financier responsable.
#    - **Revues régulières** : Encouragez les emprunteurs à vérifier régulièrement leur score de crédit et à corriger toute information erronée, ce qui peut améliorer leur capacité à obtenir un prêt.
#
# * **Revenu Mensuel** :
#    - **Assistance à l'emploi** : Proposez des programmes d'assistance à l'emploi ou de formation qui peuvent aider les emprunteurs à augmenter leurs revenus, rendant ainsi leurs demandes de prêt plus solides.

# %% [markdown]
# > **Created by Serigne Dame LO  04/11/2024 👍**
# > **serignedame2.lo@ucad.edu.sn**
# > **[e-Portfolio](https://github.com/losdame)**

# %% [markdown]
# <a id="toc"></a>
# - [0. RETOUR](#0)

# %% [markdown]
# <a id=10></a>
# - [1. RETOUR](#10)
